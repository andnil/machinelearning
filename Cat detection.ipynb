# %% [markdown]
# ## Detect cat faces

# %% [markdown]
# import the necessary packages, OpenCV, matplotlib. Load cat image

# %%
import cv2
import matplotlib.pyplot as plt

# %matplotlib inline

image = cv2.imread("data/images/cat_01.jpg")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %% [markdown]
# load the cat detector Haar cascade, then detect cat faces in the input image

# %%
detector = cv2.CascadeClassifier("data/haarcascade_frontalcatface.xml")
rects = detector.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=10, minSize=(75, 75))

# %% [markdown]
# loop over the cat faces and draw a rectangle surrounding each

# %%
for (i, (x, y, w, h)) in enumerate(rects):
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 0, 255), 2)
    cv2.putText(image, "Cat #{}".format(i + 1), (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.55, (0, 0, 255), 2)

plt.imshow(image)
plt.show()
